# %%
import pandas

# %%
pandas.read_csv("data/gapminder.tsv", sep="\t")
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df = pandas.read_csv("data/gapminder.tsv", sep="\t")

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
import pandas as pd

# %%
df = pd.read_csv("data/gapminder.tsv", sep="\t")

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.sample(5)
# Out:
#            country continent  year  lifeExp       pop     gdpPercap
# 1232        Poland    Europe  1992   70.990  38370697   7738.881247
# 742           Iraq      Asia  2002   57.046  24001816   4390.717312
# 883        Lesotho    Africa  1987   57.180   1599200    773.993214
# 1311  Saudi Arabia      Asia  1967   49.901   5618198  16903.048860
# 779          Italy    Europe  2007   80.546  58147733  28569.719700

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
(1704, 6)()
# Out:
# <>:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_10816\4140916200.py:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
#   (1704, 6)()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 (1704, 6)()
#
# TypeError: 'tuple' object is not callable

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.values
# Out:
# array([['Afghanistan', 'Asia', 1952, 28.801, 8425333, 779.4453145],
#        ['Afghanistan', 'Asia', 1957, 30.332, 9240934, 820.8530296],
#        ['Afghanistan', 'Asia', 1962, 31.997, 10267083, 853.10071],
#        ...,
#        ['Zimbabwe', 'Africa', 1997, 46.809, 11404948, 792.4499603],
#        ['Zimbabwe', 'Africa', 2002, 39.989, 11926563, 672.0386227],
#        ['Zimbabwe', 'Africa', 2007, 43.487, 12311143, 469.7092981]],
#       shape=(1704, 6), dtype=object)

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
country_df = df["country"]

# %%
country_df
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(country_df)
# Out:
# pandas.core.series.Series

# %%
df[["country"]]
# Out:
#           country
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 1699     Zimbabwe
# 1700     Zimbabwe
# 1701     Zimbabwe
# 1702     Zimbabwe
# 1703     Zimbabwe
#
# [1704 rows x 1 columns]

# %%
type(df[["country"]])
# Out:
# pandas.core.frame.DataFrame

# %%
subset = df[["country", "continent", "year"]]

# %%
subset.head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
subset.tail()
# Out:
#        country continent  year
# 1699  Zimbabwe    Africa  1987
# 1700  Zimbabwe    Africa  1992
# 1701  Zimbabwe    Africa  1997
# 1702  Zimbabwe    Africa  2002
# 1703  Zimbabwe    Africa  2007

# %%
subset.sample(5)
# Out:
#           country continent  year
# 1097  New Zealand   Oceania  1977
# 1103  New Zealand   Oceania  2007
# 802         Japan      Asia  2002
# 686       Iceland    Europe  1962
# 1031      Morocco    Africa  2007

# %%
subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 40.1+ KB

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
type(df.loc[0])
# Out:
# pandas.core.series.Series

# %%
df.loc[[0]]
# Out:
#        country continent  year  lifeExp      pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314

# %%
df.loc[[-1]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df.loc[[-1]]
#
# File ~\miniforge3\envs\BASE\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\miniforge3\envs\BASE\Lib\site-packages\pandas\core\indexing.py:1421, in _LocIndexer._getitem_axis(self, key, axis)
#    1418     if hasattr(key, "ndim") and key.ndim > 1:
#    1419         raise ValueError("Cannot index with multidimensional key")
# -> 1421     return self._getitem_iterable(key, axis=axis)
#    1423 # nested tuple slicing
#    1424 if is_nested_tuple(key, labels):
#
# File ~\miniforge3\envs\BASE\Lib\site-packages\pandas\core\indexing.py:1361, in _LocIndexer._getitem_iterable(self, key, axis)
#    1358 self._validate_key(key, axis)
#    1360 # A collection of keys
# -> 1361 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1362 return self.obj._reindex_with_indexers(
#    1363     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1364 )
#
# File ~\miniforge3\envs\BASE\Lib\site-packages\pandas\core\indexing.py:1559, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1556 ax = self.obj._get_axis(axis)
#    1557 axis_name = self.obj._get_axis_name(axis)
# -> 1559 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1561 return keyarr, indexer
#
# File ~\miniforge3\envs\BASE\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~\miniforge3\envs\BASE\Lib\site-packages\pandas\core\indexes\base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([-1], dtype='int64')] are in the [index]"

# %%
df.iloc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.iloc[-1]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
df.iloc[[0, -1]]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.loc[[0, 1, 2, 1703], ["year", "pop"]]
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 1703  2007  12311143

# %%
df.iloc[[0, 1, 2, 1703], [2, 4]]
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 1703  2007  12311143

# %%
df["lifeExp"].mean()
# Out:
# np.float64(59.474439366197174)

# %%
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
type(df.groupby('year'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df.groupby(['year'])[['lifeExp']].mean()
# Out:
#         lifeExp
# year
# 1952  49.057620
# 1957  51.507401
# 1962  53.609249
# 1967  55.678290
# 1972  57.647386
# 1977  59.570157
# 1982  61.533197
# 1987  63.212613
# 1992  64.160338
# 1997  65.014676
# 2002  65.694923
# 2007  67.007423

# %%
grouped = df.groupby(['year', 'continent'])[['lifeExp', 'gdpPercap']].mean()

# %%
grouped
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#        [   59.61055636,  7791.31401993],
#        [   71.93776667, 14283.9791096 ],
#        [   72.855     , 17283.957605  ],
#        [   51.59286538,  2481.59295975],
#        [   66.22884   ,  7506.73708808],
#        [   62.61793939,  7434.13515748],
#        [   72.8064    , 15617.89655123],
#        [   74.29      , 18554.70984   ],
#        [   53.34478846,  2282.66899126],
#        [   68.09072   ,  7793.40026112],
#        [   64.85118182,  7608.22650773],
#        [   73.64216667, 17214.31072663],
#        [   75.32      , 20448.04016   ],
#        [   53.62957692,  2281.81033324],
#        [   69.56836   ,  8044.93440552],
#        [   66.53721212,  8639.69024773],
#        [   74.4401    , 17061.5680842 ],
#        [   76.945     , 20894.045885  ],
#        [   53.59826923,  2378.7595551 ],
#        [   71.15048   ,  8889.30086256],
#        [   68.02051515,  9834.09329525],
#        [   75.50516667, 19076.7818016 ],
#        [   78.19      , 24024.17517   ],
#        [   53.32523077,  2599.38515889],
#        [   72.42204   ,  9287.67710732],
#        [   69.23387879, 10174.09039658],
#        [   76.7006    , 21711.73242243],
#        [   79.74      , 26938.77804   ],
#        [   54.80603846,  3089.03260474],
#        [   73.60812   , 11003.03162536],
#        [   70.72848485, 12473.02687013],
#        [   77.6486    , 25054.48163593],
#        [   80.7195    , 29810.188275  ]])

# %%
grouped.index
# Out:
# MultiIndex([(1952,   'Africa'),
#             (1952, 'Americas'),
#             (1952,     'Asia'),
#             (1952,   'Europe'),
#             (1952,  'Oceania'),
#             (1957,   'Africa'),
#             (1957, 'Americas'),
#             (1957,     'Asia'),
#             (1957,   'Europe'),
#             (1957,  'Oceania'),
#             (1962,   'Africa'),
#             (1962, 'Americas'),
#             (1962,     'Asia'),
#             (1962,   'Europe'),
#             (1962,  'Oceania'),
#             (1967,   'Africa'),
#             (1967, 'Americas'),
#             (1967,     'Asia'),
#             (1967,   'Europe'),
#             (1967,  'Oceania'),
#             (1972,   'Africa'),
#             (1972, 'Americas'),
#             (1972,     'Asia'),
#             (1972,   'Europe'),
#             (1972,  'Oceania'),
#             (1977,   'Africa'),
#             (1977, 'Americas'),
#             (1977,     'Asia'),
#             (1977,   'Europe'),
#             (1977,  'Oceania'),
#             (1982,   'Africa'),
#             (1982, 'Americas'),
#             (1982,     'Asia'),
#             (1982,   'Europe'),
#             (1982,  'Oceania'),
#             (1987,   'Africa'),
#             (1987, 'Americas'),
#             (1987,     'Asia'),
#             (1987,   'Europe'),
#             (1987,  'Oceania'),
#             (1992,   'Africa'),
#             (1992, 'Americas'),
#             (1992,     'Asia'),
#             (1992,   'Europe'),
#             (1992,  'Oceania'),
#             (1997,   'Africa'),
#             (1997, 'Americas'),
#             (1997,     'Asia'),
#             (1997,   'Europe'),
#             (1997,  'Oceania'),
#             (2002,   'Africa'),
#             (2002, 'Americas'),
#             (2002,     'Asia'),
#             (2002,   'Europe'),
#             (2002,  'Oceania'),
